# %% [markdown]
# # Sorting Algorithms
# ## 2. Selection Sort
#
# **Real-life example**
#
# Imagine selecting the smallest pencil from your pencil box, placing it first, then selecting the next smallest, and so on.
#
# Tell them:
# “Find the smallest item and put it at the front → repeat.”
#
# **Another example**
#
# * Choosing the oldest milk packet from a fridge shelf
# * Selecting cheapest product from a list
# * Selecting slowest person in a race and ranking them
#
# **Teaching Visualization**
#
# Array: [7, 2, 8, 1]
#
# Step 1: Find smallest → 1 → swap with first
# Step 2: Find smallest from remaining → 2 → stays
# Step 3: Find smallest from remaining → 7 → swap with 8

# %% [markdown]
# ## Selection Sort
# The Selection Sort algorithm finds the lowest value in an array and moves it to the front of the array.
# * The algorithm looks through the array again and again, moving the next lowest values to the front, until the array is sorted.
# ![image.png](attachment:image.png)
#
#
# ---
# **Resources**
# 1. [Selection Sort TutorialsPoint](https://www.tutorialspoint.com/data_structures_algorithms/selection_sort_algorithm.htm)
# 2.

# %% [markdown]
# ### Real-Life Analogy
# Imagine you are organizing books on a shelf in ascending order of size. You start by picking the smallest book (shortest in height) and placing it in the first position. Then, you find the next smallest and place it in the second position. You continue this process until all books are in order. This is exactly how Selection Sort works with different data structures!
#
#
# ### Applications of Selection Sort
# * Perfect for teaching fundamental sorting mechanisms and algorithm design.
# * Suitable for small lists where the overhead of more complex algorithms isn't justified and memory writing is costly as it requires less memory writes compared to other standard sorting algorithms.
# * Heap Sort algorithm is based on Selection Sort.

# %% [markdown]
# ### How it Work
# 1. Go through the array to find the lowest value.
# 2. Move the lowest value to the front of the unsorted part of the array.
# 3. Go through the array again as many times as there are values in the array.

# %%
array_number = [ 64,25,12,22,11]

length=len(array_number)
for i in range(length-1):
    min_elem=i
    for j in range(i+1,length):
        if array_number[j]<array_number[min_elem]:
            min_elem=j
    array_number[i],array_number[min_elem]=array_number[min_elem],array_number[i]
    print("Sorting Array",array_number)

print("Sorted Array :", array_number)
# Out:
# Sorting Array [11, 25, 12, 22, 64]
# Sorting Array [11, 12, 25, 22, 64]
# Sorting Array [11, 12, 22, 25, 64]
# Sorting Array [11, 12, 22, 25, 64]
# Sorted Array : [11, 12, 22, 25, 64]
